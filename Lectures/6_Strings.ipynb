# %% [markdown]
# <a href="https://colab.research.google.com/github/zakia16/CS1336-Computer-Science-I/blob/main/Lectures/6_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A string is a **sequence**, which means it contains multiple values in a particular order.
# In this chapter we'll see how to access the values that make up a string, and we'll use functions that process strings.

# %%
my_string = "Hello, World!"
my_string = 'Hello, World!'

# %% [markdown]
# More Examples:

# %%
my_string = "Hello, It's my World!"
my_string = 'Hello, It's my World!'  # This line will produce error

# %% [markdown]
# Entering 'Hello, It's my World!' won’t work, because Python will think the string ends after `It` and will treat the rest `(s my World!)` as invalid Python code.

# %% [markdown]
# #  Escape Sequences

# %% [markdown]
# An escape sequence lets you use characters that are otherwise impossible to put into a string literal. An escape sequence consists of a backslash `(\)` followed by the character you want to add to the string

# %%
my_string = 'Hello, It\'s my World!'  # This code will run withour error

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To practice using these, enter the following into the interactive shell:

# %%
print("Hello there!\nHow are you?\nI\'m doing fine.")

# %% [markdown]
# Fix the followings to produce correct Output:

# %%
print("C:\Users\Bob")
# Out:
# C:\Users\Bob

# %%
print("He said, "Hello There!"")
# Out:
# He said, "Hello There!"

# %% [markdown]
# # Deciding Which Loop to Use

# %% [markdown]
# **The while loop is a conditional pretest loop**
# *   Iterates as long as a certain condition exits
# *	Validating input
# *	Reading lists of data terminated by a sentinel
#
# **The for loop is a pretest loop**
# *   Built-in expressions for initializing, testing, and updating
# *   Situations where the exact number of iterations is known

# %% [markdown]
# #Practise

# %% [markdown]
# Given a non-negative number x, which expression has the range 4 to 9?
#
# A. x % 9
# B. (x % 6) + 4
# C. (x % 5) + 4
# D. (x % 10) - 1

# %% [markdown]
# Write your answer below:
#
# A or B or C or D

# %% [markdown]
# # References:
#
# https://www.geeksforgeeks.org/blogs/what-is-ide/
# https://www.teach.cs.toronto.edu/~csc148h/notes/python-recap/type_annotations.html
