# %% [markdown]
# <a href="https://colab.research.google.com/github/zakia16/CS1336-Computer-Science-I/blob/main/Lectures/loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   A loop is a program construct that repeatedly executes the loop's statements (known as the loop body) while the loop's expression is true; when false, execution proceeds past the loop. Each time through a loop's statements is called an `iteration`.
#   In Python, we mainly have three types of loops:
#   for, while, and do-while.

# %% [markdown]
# #  while Loop Statements

# %% [markdown]
# Recall that the integer division operator, //, divides two numbers and rounds down to an integer. For example, suppose the run time of a movie is 105 minutes. You might want to know how long that is in hours. Conventional division returns a floating-point number:

# %% [markdown]
# Given a non-negative number x, which expression has the range 4 to 9?
#
# A. x % 9
# B. (x % 6) + 4
# C. (x % 5) + 4
# D. (x % 10) - 1

# %% [markdown]
# Write your answer below:
#
# A or B or C or D

# %% [markdown]
# # References:
#
# https://www.geeksforgeeks.org/blogs/what-is-ide/
# https://www.teach.cs.toronto.edu/~csc148h/notes/python-recap/type_annotations.html
