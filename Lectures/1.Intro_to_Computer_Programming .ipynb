# %% [markdown]
# <a href="https://colab.research.google.com/github/zakia16/CS1336-Computer-Science-I/blob/main/Lectures/1.Intro_to_Computer_Programming%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Programming as a way of thinking
# The first goal of this book is to teach you how to program in Python. But learning to program means learning a new way to think, so the second goal of this book is to help you think like a computer scientist.
#
# We will start with the most basic elements of programming and work our way up.
#
# You will also start to learn the vocabulary of programming, including terms like operator, expression, value, and type.

# %% [markdown]
# #  1. History of Programming Languages

# %% [markdown]
# Please see class lecture for details

# %% [markdown]
# # 2. What is Python

# %% [markdown]
# Python is a high-level, interpreted, general-purpose programming language. It is widely known for its readability, clear syntax, and massive ecosystem.
#
# Please see class lecture for more.

# %% [markdown]
# ## 2.1 Installing Python

# %% [markdown]
# Please see class lecture for details

# %% [markdown]
# ## 2.2 Integrated Development Environment

# %% [markdown]
# An IDE (Integrated Development Environment) is software that combines commonly used developer tools into a compact GUI (graphical user interface) application.
# Coding can be done with simple editors like Notepad, but IDEs offer much more.
#
# **Common Features of an IDE**
#
# *   **Editor:** Typically a text editor can help you write software code by highlighting syntax with visual cues, providing language-specific auto-completion, and checking for bugs as you type.
# *   **Compiler/Interpreter:** A compiler interprets human-readable code into machine-specific code that can be executed on different operating systems like Linux, Windows, or Mac OS. Most IDEs usually come with built-in compilers for the language it supports.
# *   **Debugger:** A tool that can assist developers to test and debug their applications and graphically point out the locations of bugs or errors if any.
#
# Examples: Visual Studio Code, PyCharm, Xcode.

# %% [markdown]
# ## 2.3 The Python Interpreter Workflow

# %% [markdown]
# A Python `Interpreter` is the program that reads and executes Python code. It translates your Python instructions into machine-readable form line by line, so the computer can understand and run them.
#
# When you run a Python program, code passes through Python Interpreter, which is responsible for:
#
# - Checking your code for errors.
# - Converting it into an intermediate form called bytecode.
# - Sending it to the Python Virtual Machine (PVM) for execution.

# %% [markdown]
# Let's look at an example. Here's a classic "Hello, World!" written in Python:

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# 1. Python doesn’t run your source code directly.
#
# 2. It compiles it into bytecode.
#
# 3. The Python virtual machine executes these low-level instructions step by step.

# %% [markdown]
# To visualize this at a high level, here’s a simple diagram of how an interpreter processes your code:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# More on: https://opensource.com/article/18/4/introduction-python-bytecode

# %% [markdown]
# # 3. Python Syntax Foundations

# %% [markdown]
# ##  3.1 Your First Program

# %%
# My first Python program.
# Classic Hello World! program.
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Key Terms:**
# `statement`: a program instruction.
# `print()`function: displays variables or expression values.
# `"#"`(Comments): Notes of explanation within a program used for program documentation.
# *   They are completely ignored by the Python interpreter during execution.
# *   They are intended strictly for a human reading the program's code to make it easier to understand.

# %% [markdown]
# ## 3.2 Python Variables and Literals

# %% [markdown]
# Python syntax distinguishes between values that stay fixed and values that can change:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Hello")    # string literal

var = "Hello"     # The variable `var` is created and assigned the string literal `Hello`.
print(var)
# Out:
# Hello
# Hello

# %% [markdown]
# ## 3.3 Data Types & The `type()`Function

# %% [markdown]
# **The type() Function**
# Integer, floating-point, and string aren’t the only data types in Python. As you continue to learn about programming, you may come across values of other data types. You can always pass these to the type() function to determine what type they are.

# %%
print(type("Starbucks Latte")) #Product Name
print(type(2))    #No of cups you ordered
print(type(4.75)) #price of a cup in dollars
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## 3.4 Assignment Statements

# %% [markdown]
# You’ll store values in variables with an assignment statement. An assignment statement consists of a variable name, an equal sign (called the assignment operator), and the value to be stored. If you enter the assignment statement spam = 42, a variable named spam will have the integer value 42 stored in it.
#
# You can think of a variable as a labeled box that a value is placed in, but Chapter 6 explains how a name tag attached to the value might be a better metaphor. Both are shown in Figure 1-1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Figure 1-1: The code spam = 42 is like telling the program, “The variable spam now has the integer value 42 in it.”

# %%
spam = 40
print(spam)
# Out:
# 40

# %%
eggs = 2
print (spam + eggs)
# Out:
# 42

# %%
print(spam + eggs + spam)
# Out:
# 82

# %%
spam = spam + 2
print(spam)
# Out:
# 42

# %% [markdown]
# A variable is `initialized` (or created) the first time a value is stored in it ❶. After that, you can use it in expressions with other variables and values ❷. When a variable is assigned a new value ❸, the old value is forgotten, which is why spam evaluated to 42 instead of 40 at the end of the example. This is called overwriting the variable. Enter the following code into the interactive shell to try overwriting a string:

# %%
spam = "Hello"
spam = "Goodbye"

print(spam)

# %% [markdown]
# Just like the box in Figure 1-1, the spam variable in Figure 1-2 stores 'Hello' until you replace the string with 'Goodbye'.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Figure 1-2: When a new value is assigned to a variable, the old one is forgotten.

# %% [markdown]
# # Variable Names

# %% [markdown]
# A good variable name describes the data it contains. Imagine that you moved to a new house and labeled all of your moving boxes as Stuff. You’d never find anything! Most of this book’s examples (and Python’s documentation) use generic variable names like spam, eggs, and bacon, which come from the Monty Python “Spam” sketch. But in your programs, descriptive names will help make your code more readable.
#
# Though you can name your variables almost anything, Python does have some naming restrictions. Your variable name must obey the following four rules:
#
# * It can’t have spaces.
# * It can use only letters, numbers, and the underscore (_) character.
# * It can’t begin with a number.
# * It can’t be a Python keyword, such as if, for, return, or other keywords you’ll learn in this book.
# Table 1-3 shows examples of legal variable names.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Variable names are case-sensitive, meaning that spam, SPAM, Spam, and sPaM are four different variables. It is a Python convention to start your variables with a lowercase letter: spam instead of Spam.

# %% [markdown]
# **Python Keywords:**
# The following names are used as reserved words, or keywords of the language, and cannot be used as ordinary identifiers.
#
# ![image.png](data:image/png;base64,...)
#
# Ref: https://docs.python.org/3/reference/lexical_analysis.html#keywords

# %% [markdown]
# **Style guidelines for variables:**
# **Camel case:** numApples or peopleOnBus.
# **Sanke Case /Underscore separated:** num_apples or people_on_bus.

# %% [markdown]
# # Valid and Invalid names Checker !!!!

# %% [markdown]
# **Run the code below to test valid and invalid names:**

# %%
# @title
import keyword

def is_valid_python_name(name):
  """
  Checks if a given string is a valid Python 3 identifier and not a reserved keyword.

  Args:
    name: The string to check.

  Returns:
    True if the name is a valid, usable Python name, False otherwise.
  """
  return name.isidentifier() and not keyword.iskeyword(name)

# %%
# Type a name inside is_valid_python_name:
is_valid_python_name("2variable")
# Out:
# True

# %% [markdown]
# 🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒🆒

# %% [markdown]
# # 4. Controlling Data Output

# %% [markdown]
# ## 4.1 Newlines `(\n)`
#
# ![image.png](data:image/png;base64,...)

# %%
print(' 1\n 2\n 3')
# Out:
#  1
#  2
#  3

# %% [markdown]
# ## 4.2 Keeping Output on the Same Line `(end=)`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Including end=' ' keeps output on same line
print('Hello !.', end=' ')
print('How are you?', end=' ')
print('I am Alice.')
# Out:
# Hello !. How are you? I am Alice.

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. **Drawing a "T"**
# The following figure with x's has five lines. In the program below, print("xxxxx") outputs the figure's first line.
# Complete the program with four more print() statements to ensure the program's output matches the given figure exactly, including the number of spaces and newlines.
#
#       ![image.png](data:image/png;base64,...)

# %%
# The first line is already provided
print("xxxxx")

# 1. Output the second line (two spaces, x)


# 2. Output the third line (two spaces, x)


# 3. Output the fourth line (two spaces, x)


# 4. Output the fifth line (two spaces, x)

# %% [markdown]
# What does the variable tomato contain after the following code runs?

# %%
tomato = 20
tomato = tomato + 1

print(tomato)
# Out:
# 21

# %% [markdown]
# What should the following two expressions evaluate to?

# %%
print('spam' * 3)

# %% [markdown]
# # References:
#
# https://www.geeksforgeeks.org/blogs/what-is-ide/

# %% [markdown]
# # 👏 Awesome work!  🏆 Coding champion!
