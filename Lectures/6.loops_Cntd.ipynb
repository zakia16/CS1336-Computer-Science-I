# %% [markdown]
# <a href="https://colab.research.google.com/github/zakia16/CS1336-Computer-Science-I/blob/main/Lectures/6.loops_Cntd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #for Loops

# %% [markdown]
# A for loop iterates a specific number of times.

# %%
# @title
from IPython.display import HTML

HTML("""
<style>
  .comparison-wrapper {
    font-family: 'Courier New', Courier, monospace;
    background: #1e1e1e;
    color: #d4d4d4;
    padding: 20px;
    border-radius: 8px;
    max-width: 750px;
  }
  .grid-container {
    display: grid;
    grid-template-columns: 1fr 1fr;
    gap: 20px;
    position: relative;
  }
  .code-block {
    background: #252526;
    padding: 15px;
    border-radius: 6px;
    border: 1px solid #3c3c3c;
    font-size: 15px;
    line-height: 1.8;
  }
  .title {
    color: #569cd6;
    font-weight: bold;
    font-family: sans-serif;
    margin-bottom: 10px;
    font-size: 14px;
    text-transform: uppercase;
    letter-spacing: 1px;
  }

  /* Highlight Classes for Component Mapping */
  .init-part { transition: all 0.5s ease; padding: 2px 4px; border-radius: 4px; }
  .cond-part { transition: all 0.5s ease; padding: 2px 4px; border-radius: 4px; }
  .step-part { transition: all 0.5s ease; padding: 2px 4px; border-radius: 4px; }

  .active-init { background-color: #f14c4c; color: #ffffff; font-weight: bold; }
  .active-cond { background-color: #3794ff; color: #ffffff; font-weight: bold; }
  .active-step { background-color: #89d185; color: #000000; font-weight: bold; }

  .explanation-box {
    margin-top: 15px;
    padding: 12px;
    background: #2d2d2d;
    border-left: 4px solid #569cd6;
    font-family: sans-serif;
    font-size: 14px;
    color: #cccccc;
    min-height: 48px;
  }
  .controls {
    margin-top: 15px;
    display: flex;
    gap: 10px;
  }
  .btn-anim {
    background: #0e639c;
    color: white;
    border: none;
    padding: 8px 16px;
    border-radius: 4px;
    cursor: pointer;
    font-family: sans-serif;
    font-weight: bold;
  }
  .btn-anim:hover { background: #1177bb; }
</style>

<div class="comparison-wrapper">
  <div class="grid-container">
    <div class="code-block">
      <div class="title">WHILE LOOP (Spread Out)</div>
      <span id="w-init" class="init-part">i = 1</span><br>
      <span id="w-cond" class="cond-part">while i &lt;= 5:</span><br>
      &nbsp;&nbsp;&nbsp;&nbsp;print(i)<br>
      &nbsp;&nbsp;&nbsp;&nbsp;<span id="w-step" class="step-part">i += 1</span>
    </div>

    <div class="code-block">
      <div class="title">FOR LOOP (Condensed)</div>
      for i in range(<span id="f-init" class="init-part">1</span>, <span id="f-cond" class="cond-part">6</span>, <span id="f-step" class="step-part">1</span>):<br>
      &nbsp;&nbsp;&nbsp;&nbsp;print(i)
    </div>
  </div>

  <div id="explain" class="explanation-box">
    Click <strong>"Animate Similarities"</strong> to see how each part of the <code>while</code> loop moves into the <code>for</code> loop.
  </div>

  <div class="controls">
    <button class="btn-anim" onclick="runMappingAnimation()">Animate Similarities ▶</button>
    <button class="btn-anim" style="background:#4d4d4d;" onclick="resetMapping()">Reset ↺</button>
  </div>
</div>

<script>
  let animStep = 0;

  function resetMapping() {
    animStep = 0;
    ['w-init', 'f-init', 'w-cond', 'f-cond', 'w-step', 'f-step'].forEach(id => {
      document.getElementById(id).className = id.includes('init') ? 'init-part' : id.includes('cond') ? 'cond-part' : 'step-part';
    });
    document.getElementById('explain').innerHTML = 'Click <strong>"Animate Similarities"</strong> to see how each part of the <code>while</code> loop moves into the <code>for</code> loop.';
  }

  function runMappingAnimation() {
    resetMapping();

    // Step 1: Initialization (Start)
    setTimeout(() => {
      document.getElementById('w-init').classList.add('active-init');
      document.getElementById('f-init').classList.add('active-init');
      document.getElementById('explain').innerHTML = '<strong style="color:#f14c4c;">1. Initialization (Start Value):</strong><br><code>i = 1</code> in while loop becomes the 1st parameter in <code>range(1, ...)</code>.';
    }, 400);

    // Step 2: Condition (Stop)
    setTimeout(() => {
      document.getElementById('w-cond').classList.add('active-cond');
      document.getElementById('f-cond').classList.add('active-cond');
      document.getElementById('explain').innerHTML = '<strong style="color:#3794ff;">2. Condition (Stop Limit):</strong><br><code>while i <= 5</code> stops when i reaches 6, which maps to the 2nd parameter in <code>range(1, 6)</code>.';
    }, 2800);

    // Step 3: Increment (Step)
    setTimeout(() => {
      document.getElementById('w-step').classList.add('active-step');
      document.getElementById('f-step').classList.add('active-step');
      document.getElementById('explain').innerHTML = '<strong style="color:#89d185;">3. Increment / Step:</strong><br><code>i += 1</code> inside the while body becomes the 3rd parameter in <code>range(1, 6, 1)</code>.';
    }, 5200);

    // Step 4: Summary
    setTimeout(() => {
      document.getElementById('explain').innerHTML = '<strong>Summary:</strong> A <code>for</code> loop does NOT change the logic—it just packs initialization, condition, and increment into a single line!';
    }, 7600);
  }
</script>
""")
# Out:
# <style>
#   .comparison-wrapper {
#     font-family: 'Courier New', Courier, monospace;
#     background: #1e1e1e;
#     color: #d4d4d4;
#     padding: 20px;
#     border-radius: 8px;
#     max-width: 750px;
#   }
#   .grid-container {
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     gap: 20px;
#     position: relative;
#   }
#   .code-block {
#     background: #252526;
#     padding: 15px;
#     border-radius: 6px;
#     border: 1px solid #3c3c3c;
#     font-size: 15px;
#     line-height: 1.8;
#   }
#   .title {
#     color: #569cd6;
#     font-weight: bold;
#     font-family: sans-serif;
#     margin-bottom: 10px;
#     font-size: 14px;
#     text-transform: uppercase;
#     letter-spacing: 1px;
#   }
#
#   /* Highlight Classes for Component Mapping */
#   .init-part { transition: all 0.5s ease; padding: 2px 4px; border-radius: 4px; }
#   .cond-part { transition: all 0.5s ease; padding: 2px 4px; border-radius: 4px; }
# ...

# %% [markdown]
# Let see how to count using the range() function

# %%
''' Print 0 to 5 using loop'''
for i in range(5):
    print(i, end=' ')

# %% [markdown]
# OR

# %%
for i in range(0, 5):
    print(i, end=' ')

# %% [markdown]
# The `range()` function can also be called with three arguments. The first two arguments will be the start and stop values, and the third will be the step argument. The step is the amount by which the variable is increased after each iteration:

# %%
for i in range(0, 5, 1):
    print(i, end=' ')

# %% [markdown]
# You can actually use a while loop to do the same thing as a for loop; for loops are just more concise.

# %%
''' Print 0 to 5 using loop'''
count = 0
while count <= 5:
    print(count, end= ' ')
    count = count + 1
# Out:
# 0 1 2 3 4 5

# %% [markdown]
# Reverse Counting using the `range()` function

# %%
for i in range(4, -1, -1):
    print(i, end=' ')

# %% [markdown]
# A for loop can iterate over other containers such as strings, lists and dictionaries.

# %%
#============= General Format ======================
for variable in container:
    # Loop body: Sub-statements to execute

# Statements to execute after the for loop is complete

# %% [markdown]
# For example: We can also use a for loop to display the letters in a string.

# %%
for char in "hello world":
    print(char, end=' ')

# %% [markdown]
# Now that we can loop through the letters in a word, we can check whether it contains the letter "e".

# %%
for char in "hello world":
  if char == 'E' or char == 'e':
        print('This word has an "e"')

# %% [markdown]
# # Deciding Which Loop to Use

# %% [markdown]
# **The while loop is a conditional pretest loop**
# *   Iterates as long as a certain condition exits
# *	Validating input
# *	Reading lists of data terminated by a sentinel
#
# **The for loop is a pretest loop**
# *   Built-in expressions for initializing, testing, and updating
# *   Situations where the exact number of iterations is known

# %% [markdown]
# # Nested Loops

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. Write a program that takes a positive integer n as input and counts down to 1 on a single line separated by spaces, followed by "Blastoff!".

# %%
#Input: 5
#Output: 5 4 3 2 1 Blastoff!

# write your code here

# %% [markdown]
# 2. Write a Python Program to Find the Sum of Natural Numbers from to n.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 16
# ```
# then the output is:
# The sum of natural numbers up to 16 is 136

# %% [markdown]
# <details>
# <summary><b>Example Test Case 2</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# -3
# ```
# then the output is:
# Please enter a positive number.

# %%
# Sum of natural numbers up to n

# %% [markdown]
# 3. Write a program that takes an integer n and prints all even numbers from 2 up to n on a single line with spaces.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 10
# ```
# then the output is:
# 2 4 6 8 10

# %% [markdown]
# <details>
# <summary><b>Example Test Case 2</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 9
# ```
# then the output is:
# 2 4 6 8

# %%
# write your code here

# %% [markdown]
# 4. Write a program that takes a positive integer val as input and calculates the sum of its individual digits.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 4 3 2
# ```
# then the output is:
# 9

# %%
'''
As long as val is greater than 0:
  Add val % 10 (the rightmost digit) to your sum total.
  Divide val by 10 using integer division (val // 10) to drop the rightmost digit.
'''
# write your code here

# %% [markdown]
# 5. Write a program that keeps asking the user to enter positive numbers. The program stops when the user enters 0 or a negative number. At the end, print the largest number that was entered.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 44
# 23
# 56
# 12
# 0
# ```
# then the output is:
# 56

# %%
curr_value = int(input())

maximum_value = curr_value

# write your code here

print(f"Max value: {maximum_value}")

# %% [markdown]
# # References:
#
# https://www.geeksforgeeks.org/blogs/what-is-ide/
# https://www.teach.cs.toronto.edu/~csc148h/notes/python-recap/type_annotations.html
