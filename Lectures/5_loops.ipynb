# %% [markdown]
# <a href="https://colab.research.google.com/github/zakia16/CS1336-Computer-Science-I/blob/main/Lectures/5_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Modules

# %% [markdown]
# Section: Importing Modules
#  https://automatetheboringstuff.com/3e/chapter3.html

# %% [markdown]
# # LOOPS

# %% [markdown]
#   A loop is a program construct that repeatedly executes the loop's statements (known as the loop body) while the loop's expression is true; when false, execution proceeds past the loop. Each time through a loop's statements is called an `iteration`.
#   In Python, we mainly have three types of loops:
#   for, while, and do-while.

# %% [markdown]
# #  while Loop Statements

# %% [markdown]
# Let’s look at an **if statement** and a **while loop** that use the same condition and take the same actions based on that condition.
# Here is the code with an **if** statement:

# %%
count = 1

if count <= 5:
    print("Hello World")

# %% [markdown]
# Here is the code with a while statement:

# %%
#------------------------------------- Method 1  "Condition-Controlled Loop"--------------------
count = 1                 # 1. Initialization
while count <= 5:         # 2. Condition
    print("Hello")        #    Body
    count = count + 1     # 3. Increment / Update

# %%
#------------------------------------- Method 2 "Break-Controlled Loop" -------------------------------
count = 1
while True:
    print("Hello World")
    count = count + 1
    if count > 5:
        break

# %% [markdown]
# What happen if we don’t use “break”? or foget to update the counter?

# %% [markdown]
# ## Watch Out for Infinite Loops

# %% [markdown]
# The loop must contain code to make expression become `false`. Otherwise, the loop will have no way of stopping. Such a loop is called an `infinite loop`, because it will repeat an infinite number of times

# %% [markdown]
# The following code will cause your environment to hang or freeze; if this happens, you will need to interrupt the execution or refresh the page.

# %%
# Print "Hello“ Infinite times
count = 1
while count <= 5:
    print("Hello")
    #count += 1

# %% [markdown]
# ## `break` Statements

# %% [markdown]
# •	Stops the loop completely when a certain condition is met.
# •	The program immediately exits the loop.

# %%
for num in range(1, 6):
    if num == 3:
        break  # Exits the loop when num is 3
    print(num)

# %% [markdown]
# ##`continue` Statements

# %% [markdown]
# •	Skips the current iteration and moves to the next one.
# •	The loop does not stop but continues with the next iteration.

# %%
for num in range(1, 6):
    if num == 3:
        continue  # Skips the rest of the loop 			   # when num is 3
    print(num)

# %% [markdown]
# ##While Loop using Sentinel value

# %% [markdown]
# A sentinel value is a special value used to signal the termination of a loop. In the example below, the loop continues until the user enters 'exit', which acts as the sentinel value to stop execution.

# %%
user_input = input()

while user_input != 'exit':
	print(f"You entered: {user_input}")
	user_input = input("Type 'exit' to quit): ")

print("Exiting the program.")

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. Iterate 0 to 10 using while loop.

# %%
# write your code here

# %% [markdown]
# 2. Write a program that takes a positive integer n as input and counts down to 1 on a single line separated by spaces, followed by "Blastoff!".

# %%
#Input: 5
#Output: 5 4 3 2 1 Blastoff!

# write your code here

# %% [markdown]
# 3. Write a Python Program to Find the Sum of Natural Numbers from to n.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 16
# ```
# then the output is:
# The sum of natural numbers up to 16 is 136

# %% [markdown]
# <details>
# <summary><b>Example Test Case 2</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# -3
# ```
# then the output is:
# Please enter a positive number.

# %%
# Sum of natural numbers up to n

# %% [markdown]
# 4. Write a program that takes an integer n and prints all even numbers from 2 up to n on a single line with spaces.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 10
# ```
# then the output is:
# 2 4 6 8 10

# %% [markdown]
# <details>
# <summary><b>Example Test Case 2</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 9
# ```
# then the output is:
# 2 4 6 8

# %%
# write your code here

# %% [markdown]
# 5. Write a program that takes a positive integer val as input and calculates the sum of its individual digits.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 4 3 2
# ```
# then the output is:
# 9

# %%
# write your code here

# %% [markdown]
# 6. Write a program that keeps asking the user to enter positive numbers. The program stops when the user enters 0 or a negative number. At the end, print the largest number that was entered.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 44
# 23
# 56
# 12
# 0
# ```
# then the output is:
# 56

# %%
curr_value = int(input())

maximum_value = curr_value

# write your code here

print(f"Max value: {maximum_value}")

# %% [markdown]
# # References:
#
# https://www.geeksforgeeks.org/blogs/what-is-ide/
# https://www.teach.cs.toronto.edu/~csc148h/notes/python-recap/type_annotations.html
