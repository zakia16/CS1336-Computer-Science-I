# %% [markdown]
# <a href="https://colab.research.google.com/github/zakia16/CS1336-Computer-Science-I/blob/main/Lectures/4.Branches_Conditional_Logic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conditional Statements
#
# The main topic of this chapter is the conditional statement, which executes different code depending on the state of the program.
#
# But we’ll start with two new features: comparison operators, and logical operators.

# %% [markdown]
# # Comparison Operators
# Comparison operators, also called relational operators, compare two values and evaluate down to a single Boolean value.

# %%
5 == 5
# Out:
# True

# %%
5 == 4
# Out:
# False

# %% [markdown]
# A common error is to use a single equal sign (`=`) instead of a double equal sign (`==`).
# Remember that `=` assigns a value to a variable and `==` compares two values.

# %%
x = 5
y = 7

# %%
x == y

# %% [markdown]
#  The other operators are:

# %%
x != y               # x is not equal to y

# %%
x > y                # x is greater than y

# %%
x < y               # x is less than to y

# %%
x >= y               # x is greater than or equal to y

# %%
x <= y               # x is less than or equal to y

# %% [markdown]
# These operators can actually work with values of any data type:

# %%
'hello' == 'hello'

# %%
'hello' == 'Hello'

# %%
'hello' >= 'Hello'

# %%
42 == '42'
# Out:
# False

# %%
42 == 42.0
# Out:
# True

# %% [markdown]
# The expression 42 == '42' evaluates to False because Python considers the integer 42 to be different from the string '42'. However, Python does consider the integer 42 to be the same as the float 42.0.

# %% [markdown]
# #   Logical / Boolean operators

# %% [markdown]
# To combine boolean values into expressions, we can use **logical operators**.
# The most common are `and`, ` or`, and `not`.
# The meaning of these operators is similar to their meaning in English.
# For example, the value of the following expression is `True` only if `x` is greater than `0` *and* less than `10`.

# %%
x > 0 and x < 10

# %% [markdown]
# The following expression is `True` if *either or both* of the conditions is true, that is, if the number is divisible by 2 *or* 3:

# %%
x % 2 == 0 or x % 3 == 0

# %% [markdown]
# Finally, the `not` operator negates a boolean expression, so the following expression is `True` if `x > y` is `False`.

# %%
not x > y

# %% [markdown]
# Strictly speaking, the operands of a logical operator should be boolean expressions, but Python is not very strict.
# Any nonzero number is interpreted as `True`:

# %%
42 and True

# %% [markdown]
# This flexibility can be useful, but there are some subtleties to it that can be confusing.
# You might want to avoid it.

# %% [markdown]
# =====================================================================================

# %% [markdown]
# # Conditional Statements
#
# Conditional statements are used to execute code based on whether a certain condition is true or false. They help control the flow of a program by allowing different actions to be taken based on the outcome of a condition.

# %% [markdown]
# #  Conditions and Blocks of Code

# %% [markdown]
# https://automatetheboringstuff.com/3e/chapter2.html

# %%
# @title Default title text
import time
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from IPython.display import clear_output

def visualize_memory_step(step, user_num=None, div_remainder=None, console_output=""):
    fig, ax = plt.subplots(figsize=(10, 4.5))
    fig.patch.set_facecolor('#FFFFFF')
    ax.set_facecolor('#FFFFFF')

    # --- Left Side: Code Block ---
    code_lines = [
        'user_num = int(input("Enter a number: "))',
        'div_remainder = user_num % 2',
        'if div_remainder == 0:',
        '    print(f"{user_num} is even.")',
        'else:',
        '    print(f"{user_num} is odd.")'
    ]

    # Outer light-blue container
    ax.add_patch(Rectangle((0.2, 0.5), 5.5, 4.0, facecolor='#D0E6FF', edgecolor='none'))

    # Highlight current line with blue border/fill
    active_line_map = {1: 0, 2: 1, 3: 2, 4: (3 if div_remainder == 0 else 5)}
    current_idx = active_line_map.get(step, -1)

    for i, line in enumerate(code_lines):
        y_pos = 4.0 - (i * 0.55)
        if i == current_idx:
            # Selection highlight
            ax.add_patch(Rectangle((0.3, y_pos - 0.12), 5.3, 0.45,
                                   facecolor='#EBF3FF', edgecolor='#2B78E4', lw=2))
        ax.text(0.4, y_pos, line, fontfamily='monospace', fontsize=11,
                color='#000000', va='center')

    # Step indicators at top
    for s in range(1, 5):
        color = '#2B78E4' if s == step else '#444444'
        ax.text(0.5 + (s * 0.4), 4.8, str(s), fontsize=14, weight='bold', color=color)
        if s == step:
            ax.plot([0.4 + (s * 0.4), 0.6 + (s * 0.4)], [4.65, 4.65], color='#D85000', lw=3)

    # --- Right Side: Memory Stack ---
    ax.text(7.5, 4.5, "Memory", fontsize=12, ha='center', weight='bold', color='#333333')

    addresses = [95, 96, 97, 98]
    vals = [
        "",
        str(div_remainder) if div_remainder is not None else "",
        str(user_num) if user_num is not None else "",
        ""
    ]
    labels = ["", "div_remainder", "user_num", ""]

    for i, addr in enumerate(addresses):
        y_pos = 3.7 - (i * 0.7)
        # Memory address label
        ax.text(6.6, y_pos + 0.25, str(addr), fontsize=11, ha='right', va='center', color='#333333')
        # Memory box
        ax.add_patch(Rectangle((6.8, y_pos), 1.4, 0.5, facecolor='#FFDAB9', edgecolor='#D85000', lw=1.5))
        # Stored value inside box
        ax.text(7.5, y_pos + 0.25, vals[i], fontsize=11, ha='center', va='center', weight='bold')
        # Variable name on right
        ax.text(8.3, y_pos + 0.25, labels[i], fontsize=11, ha='left', va='center', fontfamily='monospace')

    # Console output preview
    if console_output:
        ax.text(0.3, 0.1, f"Output: {console_output}", fontsize=11,
                fontfamily='monospace', color='#008000', weight='bold')

    ax.set_xlim(0, 10)
    ax.set_ylim(0, 5.2)
    ax.axis('off')
    plt.tight_layout()
    plt.show()

# --- Run Interactive Step Simulation ---
user_input = int(input("Enter a number: "))
rem = user_input % 2
output_text = f"{user_input} is even." if rem == 0 else f"{user_input} is odd."

# Execution steps animation
steps = [
    (1, None, None, ""),
    (2, user_input, None, ""),
    (3, user_input, rem, ""),
    (4, user_input, rem, output_text)
]

for step_num, val_num, val_rem, out in steps:
    clear_output(wait=True)
    visualize_memory_step(step_num, val_num, val_rem, out)
    time.sleep(1.5)

# %% [markdown]
# #  Flow Control Statements:

# %% [markdown]
# Now let's explore `if` statements which is the core decisions (or flowchart diamonds) of flow control.

# %% [markdown]
# #  `if` statements

# %% [markdown]
# In order to write useful programs, we almost always need the ability to
# check conditions and change the behavior of the program accordingly.
# **Conditional statements** give us this ability. The simplest form is
# the `if` statement:

# %% [markdown]
# **Syntax**

# %%
if condition:
    # block of code to be executed if the condition is true

# %% [markdown]
# **Example**

# %%
if x > 0:
    print('x is positive')

# %% [markdown]
# `if` is a Python keyword.
# `if` statements have the same structure as function definitions: a
# header followed by an indented statement or sequence of statements called a **block**.
#
# The boolean expression after `if` is called the **condition**.
# If it is true, the statements in the indented block run. If not, they don't.
#
# There is no limit to the number of statements that can appear in the block, but there has to be at least one.
# Occasionally, it is useful to have a block that does nothing -- usually as a place keeper for code you haven't written yet.
# In that case, you can use the `pass` statement, which does nothing.

# %%
if x < 0:
    pass          # TODO: need to handle negative values!

# %% [markdown]
# The word `TODO` in a comment is a conventional reminder that there's something you need to do later.

# %% [markdown]
# ## The `else` clause
#
# An `if` statement can have a second part, called an `else` clause.
# The syntax looks like this:

# %% [markdown]
# **Syntax**

# %%
if condition:
    # block of code to be executed if the condition is true
else:
    # block of code to be executed if the condition is false

# %% [markdown]
# **Example**

# %%
x = int(input())

if x % 2 == 0:
    print('x is even')
else:
    print('x is odd')

# %% [markdown]
# If the condition is true, the first indented statement runs; otherwise, the second indented statement runs.
#
# In this example, if `x` is even, the remainder when `x` is divided by `2` is `0`, so the condition is true and the program displays `x is even`.
# If `x` is odd, the remainder is `1`, so the condition
# is false, and the program displays `x is odd`.
#
# Since the condition must be true or false, exactly one of the alternatives will run.
# The alternatives are called **branches**.

# %% [markdown]
# Let's visualize: https://pythontutor.com/visualize.html#mode=edit

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **More Example**: Voting Eligibility

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")

# %% [markdown]
# # The `elif` clause / Chained conditionals
#
# Sometimes there are more than two possibilities and we need more than two branches.
# One way to express a computation like that is a **chained conditional**, which includes an `elif` clause.

# %% [markdown]
# **Syntax**

# %%
if condition1:
    # block of code to be executed if condition1 is true
elif condition2:
    # block of code to be executed if condition2 is true
.........................................................
.........................................................

else:
    # block of code to be executed if none of the above conditions are true

# %% [markdown]
# **Example**

# %%
if x < y:
    print('x is less than y')
elif x > y:
    print('x is greater than y')
else:
    print('x and y are equal')

# %% [markdown]
# `elif` is an abbreviation of "else if".
# There is no limit on the number of `elif` clauses.
# If there is an `else` clause, it has to be at the end, but there doesn't have to be
# one.
#
# Each condition is checked in order.
# If the first is false, the next is checked, and so on.
# If one of them is true, the corresponding branch runs and the `if` statement ends.
# Even if more than one condition is true, only the first true branch runs.

# %% [markdown]
# **More Example**: Grading System

# %%
marks = int(input("Enter your marks: "))

if marks >= 90:
    grade = 'A'
elif marks >= 80:
    grade = 'B'
elif marks >= 70:
    grade = 'C'
elif marks >= 60:
    grade = 'D'
else:
    grade = 'F'

print(f"Your grade is: {grade}")

# %% [markdown]
# # Nested Conditionals
#
# One conditional can also be nested within another.
# We could have written the example in the previous section like this:

# %% [markdown]
# **Syntax**

# %%
if condition1:
    # block of code to be executed if condition1 is true
    if condition2:
        # block of code to be executed if condition1 and condition2 are true
    else:
        # block of code to be executed if condition1 is true and condition2 is false
else:
    # block of code to be executed if condition1 is false

# %% [markdown]
# **Example**

# %%
if x < y:
    print('x is less than y')
else:
    if x > y:
        print('x is greater than y')
    else:
        print('x and y are equal')

# %% [markdown]
# The outer `if` statement contains two branches.
# The first branch contains a simple statement. The second branch contains another `if` statement, which has two branches of its own.
# Those two branches are both simple statements, although they could have been conditional statements as well.
#
# Although the indentation of the statements makes the structure apparent, **nested conditionals** can be difficult to read.
# I suggest you avoid them when you can.
#
# **Logical operators** often provide a way to simplify nested conditional statements.
# Here's an example with a nested conditional.

# %%
if 0 < x:
    if x < 10:
        print('x is a positive single-digit number.')

# %% [markdown]
# The `print` statement runs only if we make it past both conditionals, so we get the same effect with the `and` operator.

# %%
if 0 < x and x < 10:
    print('x is a positive single-digit number.')

# %% [markdown]
# For this kind of condition, Python provides a more concise option:

# %%
if 0 < x < 10:
    print('x is a positive single-digit number.')

# %% [markdown]
# # Order of Operations:
# [w3schools](https://www.w3schools.com/python/python_operators_precedence.asp)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Debugging
#
# Please follow 5.12 from https://allendowney.github.io/ThinkPython/chap05.html

# %% [markdown]
# Indentation Errors: Ensure proper indentation to avoid syntax errors.
# Logical Errors: Carefully check your conditions to avoid logical errors.
# Using Multiple elif Statements: Too many elif statements can make the code hard to read.

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. Write a program that reads an integer from input and uses the modulus operator (% 2) to determine if the number is even or odd.
# This time use **conditionals**.

# %%
# 1. Read an integer from input
num = int(input())

# 2. Check if num is even (True) or odd (False) using % 2, the print "Even" for even numbers and "Odd" for odd numbers

# %% [markdown]
# 2. Write a program that takes a number from the user and checks whether it is positive, negative, or zero using if, elif, and else

# %%
num = float(input("Enter a number: "))

# Write your solution here

# %% [markdown]
#   3. Write a Python program that implements the decision logic shown in the flowchart.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
score = int(input("Enter score: "))

# Write your solution here

# %% [markdown]
#   4. Read two integers from the user and determine which one is larger, or if they are equal.

# %% [markdown]
# <details>
# <summary><b>Example Test Case1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 15
# 7
# ```
# then the output is:
# 15

# %% [markdown]
# <details>
# <summary><b>Example Test Case2</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# -3
# 4
# ```
# then the output is:
# 4

# %% [markdown]
# <details>
# <summary><b>Example Test Case3</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 42
# 42
# ```
# then the output is:
# Both numbers are equal.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

# Write your solution here

# %% [markdown]
#   5. Write a program that reads two strings from input and determines which string is longer, or if they have the same length.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# elephant
# cat
# ```
# then the output is:
# elephant

# %% [markdown]
# <details>
# <summary><b>Example Test Case 2</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# java
# python
# ```
# then the output is:
# python

# %% [markdown]
# <details>
# <summary><b>Example Test Case 3</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# code
# java
# ```
# then the output is:
# Both strings have the same length.

# %%
str1 = input()
str2 = input()

# Write your solution here

# %% [markdown]
#   6. Write a program that reads three integers from input and outputs the smallest value.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 7
# 15
# 32
# ```
# then the output is:
# 7

# %% [markdown]
# <details>
# <summary><b>Example Test Case 2</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 12
# -5
# 8
# ```
# then the output is:
# -5

# %% [markdown]
# <details>
# <summary><b>Example Test Case 3</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 4
# 4
# 9
# ```
# then the output is:
# 4

# %%
a = int(input())
b = int(input())
c = int(input())

# Write your solution here

# %% [markdown]
#   7. Write a program that calculates ticket price based on age and whether it is a weekend (True or False).
#   *   Base price for Adults (age 13–64) is 12 dollars on weekdays, 15 dollars on weekends.
#   *   Children (under 13) and Seniors (65+) receive a discount: 8 dollars on weekdays, 10 dollars on weekends.

# %% [markdown]
# <details>
# <summary><b>Example Test Case 1</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 25
# no
# ```
# then the output is:
# Ticket price: $12

# %% [markdown]
# <details>
# <summary><b>Example Test Case 2</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 30
# yes
# ```
# then the output is:
# Ticket price: $15

# %% [markdown]
# <details>
# <summary><b>Example Test Case 3</b></summary>
#
# <br>
#
# Ex: If the input is:
#
# ```text
# 10
# yes
# ```
# then the output is:
# Ticket price: $10

# %%
age = int(input("Enter age: "))
is_weekend = input("Is it the weekend? (yes/no): ") == "yes"

# Write your solution here
# Out:
# Enter age: 12
# Is it the weekend? (yes/no): yes

# %% [markdown]
# 8. Write a Python program that reads two choices from input (player1 and player2) and determines the winner based on the rules shown in the diagram:
#
# *   Rock beats Scissors
# *   Scissors beats Paper
# *   Paper beats Rock
# *   If both choices are the same, it is a Tie.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
user_choice = input("Your entry: ").strip().lower()
computer_choice = input("Computer generated: ").strip().lower()

# Write your solution here

# %% [markdown]
# # References:
#
# https://automatetheboringstuff.com/3e/chapter2.html
# https://allendowney.github.io/ThinkPython/chap05.html
